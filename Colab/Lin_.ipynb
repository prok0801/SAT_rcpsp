# %%
pip install python-sat
# Out:
# Collecting python-sat
#   Downloading python_sat-1.8.dev13-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from python-sat) (1.16.0)
# Downloading python_sat-1.8.dev13-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_28_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 31.7 MB/s eta 0:00:00
# Installing collected packages: python-sat
# Successfully installed python-sat-1.8.dev13

# %%
from pysat.solvers import Glucose3

# %%
# Tạo lớp biến hỗ trợ tương tự như VariableFactory trong Java
class VariableFactory:
    def __init__(self):
        # Khởi tạo đếm số lượng biến (bắt đầu từ 1)
        self.var_count = 1

        # Lưu trữ các biến theo tên (tên -> id biến)
        self.vars = {}

        # Lưu trữ các biến theo id (id -> tên biến)
        self.reverse_vars = {}

    # Hàm lấy id của một biến từ tên, nếu chưa có biến đó thì tạo mới
    def get_var(self, name):
        # Nếu tên biến chưa tồn tại trong self.vars, tạo mới id cho biến đó
        if name not in self.vars:
            # Gán id mới cho biến
            self.vars[name] = self.var_count
            # Lưu tên của biến theo id mới
            self.reverse_vars[self.var_count] = name
            # Tăng số lượng biến
            self.var_count += 1
        # Trả về id của biến đã được tạo ra (hoặc đã tồn tại)
        return self.vars[name]

    # Hàm tạo biến bắt đầu của hoạt động tại một thời điểm
    def start(self, activity_id, time):
        # Tạo tên biến theo cú pháp 'start_{activity_id}_{time}'
        return self.get_var(f'start_{activity_id}_{time}')

    # Hàm tạo biến chạy của hoạt động tại một thời điểm
    def run(self, activity_id, time):
        # Tạo tên biến theo cú pháp 'run_{activity_id}_{time}'
        return self.get_var(f'run_{activity_id}_{time}')

    # Hàm tạo biến tiêu thụ tài nguyên của hoạt động tại một thời điểm
    def consume(self, activity_id, resource_id, time, index):
        # Tạo tên biến theo cú pháp 'consume_{activity_id}_{resource_id}_{time}_{index}'
        return self.get_var(f'consume_{activity_id}_{resource_id}_{time}_{index}')

    # Hàm tạo biến phụ trợ (auxiliary variable) tại một thời điểm
    def aux(self, time):
        # Tạo tên biến theo cú pháp 'aux_{time}'
        return self.get_var(f'aux_{time}')

    # Hàm lấy tên của một biến từ id của nó
    def get_var_name(self, var_id):
        # Trả về tên của biến từ id, nếu không tìm thấy trả về None
        return self.reverse_vars.get(var_id, None)

# %%
# Khởi tạo bộ giải SAT và factory tạo biến
solver = Glucose3()
vf = VariableFactory()

# %%
# Hàm thêm mệnh đề vào solver
def add_clause(solver, clause):
    solver.add_clause(clause)

# %% [markdown]
# Các hàm encode_relation_fs, encode_relation_ss, encode_relation_ff, và encode_relation_sf bên dưới mô tả các phép toán liên quan đến quan hệ thứ tự giữa các hoạt động trong một bài toán lập lịch dự án (sử dụng SAT). Các phép toán này được sử dụng để mô hình hóa các ràng buộc thứ tự giữa các hoạt động (activities). Mỗi hàm mô phỏng một loại quan hệ khác nhau.
#
# - Quan hệ Finish-to-Start (FS) có nghĩa là hoạt động thứ hai (activity2) không thể bắt đầu cho đến khi hoạt động thứ nhất (activity1) kết thúc. Điều này có thể được hiểu là: activity2 bắt đầu sau khi activity1 hoàn thành.
# - Mục tiêu: Đảm bảo rằng không có thời điểm nào activity2 có thể bắt đầu cho đến khi activity1 hoàn thành.
#
# - Quan hệ Start-to-Start (SS) có nghĩa là hoạt động thứ hai (activity2) không thể bắt đầu cho đến khi hoạt động thứ nhất (activity1) bắt đầu. Điều này có thể được hiểu là: activity2 không thể bắt đầu trước khi activity1 bắt đầu.
# - Mục tiêu: Đảm bảo rằng activity2 không thể bắt đầu trước khi activity1 bắt đầu.
#
# - Quan hệ Finish-to-Finish (FF) có nghĩa là hoạt động thứ hai (activity2) không thể hoàn thành trước khi hoạt động thứ nhất (activity1) hoàn thành. Điều này có thể được hiểu là: activity2 chỉ có thể kết thúc sau khi activity1 kết thúc.
# - Mục tiêu: Đảm bảo rằng activity2 không thể hoàn thành trước khi activity1 kết thúc.
#
# - Quan hệ Start-to-Finish (SF) có nghĩa là hoạt động thứ hai (activity2) không thể hoàn thành cho đến khi hoạt động thứ nhất (activity1) bắt đầu. Điều này có thể được hiểu là: activity2 không thể hoàn thành cho đến khi activity1 bắt đầu.
# - Mục tiêu: Đảm bảo rằng activity2 không thể kết thúc trước khi activity1 bắt đầu.

# %%
# Phép toán (1) đến (4): Quan hệ thứ tự giữa các hoạt động

# encode_relation_fs: Quan hệ "Finish-to-Start" (FS)
def encode_relation_fs(solver, vf, max_time, activity1_id, activity2_id, duration1):
    for t in range(max_time):
        start1 = vf.start(activity1_id, t) # Tạo biến bắt đầu của activity1 tại thời điểm t
        for k in range(t + duration1):     # Kiểm tra tất cả thời điểm k từ t đến (t + duration1)
            add_clause(solver, [-start1, -vf.start(activity2_id, k)]) # Không thể bắt đầu activity2 tại thời điểm k


# encode_relation_ss: Quan hệ "Start-to-Start" (SS)
def encode_relation_ss(solver, vf, max_time, activity1_id, activity2_id):
    for t in range(max_time):
        start1 = vf.start(activity1_id, t) # Tạo biến bắt đầu của activity1 tại thời điểm t
        for k in range(t):                 # Kiểm tra các thời điểm trước thời điểm t
            add_clause(solver, [-start1, -vf.start(activity2_id, k)]) # Không thể bắt đầu activity2 tại thời điểm k

# encode_relation_ff: Quan hệ "Finish-to-Finish" (FF)
def encode_relation_ff(solver, vf, max_time, activity1_id, activity2_id, duration1, duration2):
    for t in range(max_time - duration2):
        start1 = vf.start(activity1_id, t)         # Tạo biến bắt đầu của activity1 tại thời điểm t
        for k in range(t + duration1 - duration2): # Kiểm tra thời điểm k sau khi (t + duration1 - duration2)
            add_clause(solver, [-start1, -vf.start(activity2_id, k)]) # Không thể bắt đầu activity2 tại thời điểm k

# encode_relation_sf: Quan hệ "Start-to-Finish" (SF)
def encode_relation_sf(solver, vf, max_time, activity1_id, activity2_id, duration2):
    for t in range(max_time):
        start1 = vf.start(activity1_id, t)         # Tạo biến bắt đầu của activity1 tại thời điểm t
        for k in range(max(0, t - duration2 + 1)): # Kiểm tra các thời điểm trước thời điểm t + duration2
            add_clause(solver, [-start1, -vf.start(activity2_id, k)]) # Không thể bắt đầu activity2 tại thời điểm k

# %% [markdown]
# Phép toán (6) trong bài toán lập lịch yêu cầu đảm bảo rằng mỗi hoạt động chỉ có một thời điểm bắt đầu duy nhất. Với mỗi hoạt động, phải chắc chắn rằng không thể có hai thời điểm mà tại đó hoạt động này bắt đầu cùng một lúc.
#
# Mục đích của hàm encode_unique_start_instant:
# Hàm này sẽ tạo ra các mệnh đề SAT để đảm bảo rằng mỗi hoạt động có chỉ một thời điểm duy nhất để bắt đầu trong khoảng thời gian max_time.

# %%
# Phép toán (6): Mỗi hoạt động có thời điểm bắt đầu duy nhất
def encode_unique_start_instant(solver, vf, max_time, activity_id):
    # Tạo một mệnh đề đảm bảo rằng hoạt động phải bắt đầu vào một thời điểm nào đó trong khoảng từ 0 đến max_time-1
    clause = [vf.start(activity_id, t) for t in range(max_time)]  # Tạo mảng các biến start của hoạt động activity_id tại các thời điểm t
    add_clause(solver, clause)  # Thêm mệnh đề: ít nhất một trong các biến start phải đúng, nghĩa là hoạt động phải bắt đầu tại một thời điểm nào đó

    # Tạo mệnh đề đảm bảo rằng không thể có hai thời điểm bắt đầu cùng lúc
    for t1 in range(max_time):  # Lặp qua tất cả các thời điểm t1 từ 0 đến max_time-1
        for t2 in range(t1 + 1, max_time):  # Lặp qua các thời điểm t2 sau t1
            # Thêm mệnh đề: nếu hoạt động bắt đầu tại thời điểm t1 thì nó không thể bắt đầu tại thời điểm t2
            add_clause(solver, [-vf.start(activity_id, t1), -vf.start(activity_id, t2)])

# %% [markdown]
# Phép toán (7) trong bài toán lập lịch yêu cầu rằng hoạt động không thể bắt đầu quá muộn. Điều này có nghĩa là thời điểm bắt đầu của một hoạt động phải nằm trong một phạm vi hợp lý, không thể muộn hơn một thời điểm nhất định. Cụ thể, nếu một hoạt động có thời gian thực hiện (duration), thì thời điểm bắt đầu của nó không thể muộn hơn một mốc thời gian nhất định mà tại đó nó sẽ không kịp hoàn thành.
#
# Mục đích của hàm encode_start_in_time:
# Hàm này sẽ tạo ra các mệnh đề SAT để đảm bảo rằng hoạt động activity_id không thể bắt đầu quá muộn, tức là thời điểm bắt đầu của nó phải nằm trong khoảng từ 0 đến max_time - duration.

# %%
# Phép toán (7): Hoạt động không thể bắt đầu quá muộn
def encode_start_in_time(solver, vf, max_time, activity_id, duration):
    for t in range(max_time - duration + 1, max_time):  #Lặp qua các thời điểm bắt đầu hợp lệ
        add_clause(solver, [-vf.start(activity_id, t)]) #Thêm mệnh đề SAT đảm bảo rằng không thể bắt đầu tại các thời điểm quá muộn

# %% [markdown]
# Mục đích của hàm encode_runtime:
# Hàm này tạo ra các mệnh đề SAT để đảm bảo rằng một khi một hoạt động bắt đầu tại một thời điểm t, nó sẽ tiếp tục thực hiện trong suốt duration đơn vị thời gian và không thể thực hiện trước khi bắt đầu hoặc sau khi kết thúc.

# %%
# Phép toán (8) và (9): Thời gian thực hiện
def encode_runtime(solver, vf, max_time, activity_id, duration):
    for t in range(max_time):  # Lặp qua tất cả các thời điểm t từ 0 đến max_time-1
        start_literal = vf.start(activity_id, t)  # Biến biểu thị việc hoạt động bắt đầu tại thời điểm t
        for j in range(max_time):  # Lặp qua tất cả các thời điểm j từ 0 đến max_time-1
            run_literal = vf.run(activity_id, j)  # Biến biểu thị việc hoạt động đang chạy tại thời điểm j
            if j < t:  # Nếu thời điểm j trước thời điểm t
                add_clause(solver, [-start_literal, -run_literal])  # Mệnh đề: Nếu hoạt động không bắt đầu tại t, thì không thể chạy tại j
            elif t <= j < t + duration:  # Nếu thời điểm j nằm trong khoảng từ t đến t+duration-1
                add_clause(solver, [-start_literal, run_literal])  # Mệnh đề: Nếu hoạt động bắt đầu tại t, thì hoạt động phải chạy tại j
            else:  # Nếu thời điểm j sau thời gian thực hiện của hoạt động (sau t + duration - 1)
                add_clause(solver, [-start_literal, -run_literal])  # Mệnh đề: Nếu hoạt động không bắt đầu tại t, thì không thể chạy tại j

# %%
# Phép toán (10): Quan hệ kết thúc-bắt đầu
def encode_relation_fs(solver, vf, max_time, activity1_id, activity2_id, duration1):
    for t in range(max_time):
        start1 = vf.start(activity1_id, t)
        for k in range(t + duration1):
            add_clause(solver, [-start1, -vf.start(activity2_id, k)])

# %%
# Phép toán (11): Quan hệ bắt đầu-bắt đầu (Start-to-Start, SS)
def encode_relation_ss(solver, vf, max_time, activity1_id, activity2_id):
    for t in range(max_time):
        start1 = vf.start(activity1_id, t)
        for k in range(t):
            add_clause(solver, [-start1, -vf.start(activity2_id, k)])

# Phép toán (12): Quan hệ kết thúc-kết thúc (Finish-to-Finish, FF)
def encode_relation_ff(solver, vf, max_time, activity1_id, activity2_id, duration1, duration2):
    for t in range(max_time - duration1 + 1):
        finish1 = vf.start(activity1_id, t)  # end of activity1
        for k in range(max_time - duration2 + 1):
            if k < t + duration1 - duration2:
                add_clause(solver, [-finish1, -vf.start(activity2_id, k)])

# Phép toán (13): Quan hệ bắt đầu-kết thúc (Start-to-Finish, SF)
def encode_relation_sf(solver, vf, max_time, activity1_id, activity2_id, duration2):
    for t in range(max_time):
        start1 = vf.start(activity1_id, t)
        for k in range(t + duration2, max_time):
            add_clause(solver, [-start1, -vf.start(activity2_id, k)])

# Use encode_relation_ss, encode_relation_ff, and encode_relation_sf when encoding
# add specific cases based on the relations list:
for relation in relations:
    if relation["relation_type"] == "ea":
        encode_relation_fs(solver, vf, max_time, relation["task_id_1"], relation["task_id_2"],
                           next(a["duration"] for a in activities if a["id"] == relation["task_id_1"]))
    elif relation["relation_type"] == "ss":
        encode_relation_ss(solver, vf, max_time, relation["task_id_1"], relation["task_id_2"])
    elif relation["relation_type"] == "ff":
        encode_relation_ff(solver, vf, max_time, relation["task_id_1"], relation["task_id_2"],
                           next(a["duration"] for a in activities if a["id"] == relation["task_id_1"]),
                           next(a["duration"] for a in activities if a["id"] == relation["task_id_2"]))
    elif relation["relation_type"] == "sf":
        encode_relation_sf(solver, vf, max_time, relation["task_id_1"], relation["task_id_2"],
                           next(a["duration"] for a in activities if a["id"] == relation["task_id_2"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5ce3b5c4120b> in <cell line: 25>()
#      23 # Use encode_relation_ss, encode_relation_ff, and encode_relation_sf when encoding
#      24 # add specific cases based on the relations list:
# ---> 25 for relation in relations:
#      26     if relation["relation_type"] == "ea":
#      27         encode_relation_fs(solver, vf, max_time, relation["task_id_1"], relation["task_id_2"],
#
# NameError: name 'relations' is not defined

# %% [markdown]
# Mục đích của hàm encode_workload:
# Hàm encode_workload thêm các ràng buộc vào bộ giải SAT để đảm bảo rằng tại mỗi thời điểm trong khoảng thời gian từ 0 đến max_time - 1, có ít nhất một hoạt động đang chạy. Nó sử dụng một biến phụ aux_t tại mỗi thời điểm t để biểu diễn việc "lấp đầy" thời gian đó với các hoạt động.

# %%
# Phép toán (14) và (15): Đảm bảo không có thời gian trống trong lịch trình
def encode_workload(solver, vf, max_time, activities):
    aux_vars = []  # Danh sách chứa các biến phụ cho mỗi thời điểm t
    for t in range(max_time):  # Lặp qua tất cả các thời điểm từ 0 đến max_time-1
        aux_t = vf.aux(t)  # Tạo một biến phụ aux_t cho thời điểm t
        aux_vars.append(aux_t)  # Thêm biến phụ vào danh sách aux_vars
        clause = [-aux_t] + [vf.run(activity["id"], t) for activity in activities]
        add_clause(solver, clause)  # Mệnh đề: Nếu không có hoạt động nào chạy tại t, thì aux_t phải là False

        # Đảm bảo rằng nếu aux_t là True (tức là có ít nhất một hoạt động đang chạy tại t),
        # thì phải có ít nhất một hoạt động đang chạy tại thời điểm t
        for activity in activities:
            add_clause(solver, [aux_t, -vf.run(activity["id"], t)])

    # Đảm bảo rằng không có thời gian trống liên tiếp trong lịch trình
    for i in range(len(aux_vars) - 1):
        add_clause(solver, [aux_vars[i], -aux_vars[i + 1]])

# %%
# Phép toán (16): Mã hóa các atoms tiêu thụ tài nguyên
def encode_consumption_atoms(solver, vf, max_time, activities, resources):
    for t in range(max_time):
        for activity in activities:
            for resource in resources:
                consumption = activity['consumption'].get(resource['id'], 0)
                # Tạo các biến tiêu thụ tài nguyên nếu cần thiết
                for i in range(consumption):
                    consumption_var = vf.consume(activity["id"], resource["id"], t, i)
                    add_clause(solver, [-vf.run(activity["id"], t), consumption_var])

# %% [markdown]
# Phép toán (5) và (17) trong bài toán lập lịch dự án với ràng buộc tài nguyên yêu cầu rằng các tài nguyên không được vượt quá dung lượng của chúng tại mỗi thời điểm trong lịch trình. Điều này có nghĩa là tại mỗi thời điểm t, tổng lượng tài nguyên mà các hoạt động tiêu thụ không được vượt quá số lượng tài nguyên có sẵn.
#
# Hàm encode_resource_constraint chịu trách nhiệm mã hóa các ràng buộc này trong SAT solver. Nó kiểm tra lượng tài nguyên tiêu thụ của các hoạt động tại mỗi thời điểm t và đảm bảo rằng tổng lượng tài nguyên tiêu thụ không vượt quá dung lượng của tài nguyên đó.

# %%
# Phép toán (5) và (17): Ràng buộc tài nguyên
def encode_resource_constraint(solver, vf, max_time, activities, resources):
    for t in range(max_time):  # Lặp qua tất cả các thời điểm từ 0 đến max_time-1
        for resource in resources:  # Lặp qua tất cả các tài nguyên
            consumption_vars = []  # Danh sách chứa các biến thể hiện việc tiêu thụ tài nguyên tại thời điểm t
            for activity in activities:  # Lặp qua tất cả các hoạt động
                if activity["consumption"].get(resource["id"], 0) > 0:  # Kiểm tra hoạt động có tiêu thụ tài nguyên này không
                    for i in range(activity["consumption"][resource["id"]]):  # Lặp qua số lượng tài nguyên mà hoạt động tiêu thụ
                        consumption_vars.append(vf.consume(activity["id"], resource["id"], t, i))  # Tạo biến cho mỗi đơn vị tài nguyên
                        add_clause(solver, [-vf.run(activity["id"], t), consumption_vars[-1]])  # Ràng buộc: Nếu hoạt động không chạy tại t thì không tiêu thụ tài nguyên
            if consumption_vars:  # Nếu có bất kỳ tài nguyên nào được tiêu thụ tại thời điểm t
                gen_cardinality_constraint(solver, consumption_vars, resource["capacity"])  # Đảm bảo tổng tài nguyên tiêu thụ không vượt quá dung lượng của tài nguyên

# %% [markdown]
# Hàm gen_cardinality_constraint có nhiệm vụ thêm các ràng buộc về giới hạn số lượng cho các biến boolean trong SAT solver. Cụ thể, nó đảm bảo rằng không có quá nhiều biến trong danh sách variables có giá trị True đồng thời, giới hạn số lượng này bởi một giá trị bound được chỉ định.

# %%
# Hàm giới hạn số lượng
def gen_cardinality_constraint(solver, variables, bound):
  # Nếu số lượng biến trong list nhỏ hơn hoặc bằng giới hạn, không cần phải thêm bất kỳ ràng buộc nào
    if len(variables) <= bound:
        return
    for i in range(len(variables) - bound): # Lặp qua danh sách các biến
        add_clause(solver, [-var for var in variables[i:i + bound + 1]])  # Thêm ràng buộc vào solver

# %%
# Giải mã lời giải thành thông tin dễ hiểu
def decode_solution(model, vf):
    decoded_solution = {
        "activities_start_times": {},
        "activities_runtime": [],
        "resources_usage": []
    }

    for var in model:
        if var > 0:
            var_name = vf.get_var_name(abs(var))
            if "start" in var_name:
                parts = var_name.split('_')
                activity_id = int(parts[1])
                time = int(parts[2])
                decoded_solution["activities_start_times"][activity_id] = time
            elif "run" in var_name:
                parts = var_name.split('_')
                activity_id = int(parts[1])
                time = int(parts[2])
                decoded_solution["activities_runtime"].append((activity_id, time))
            elif "consume" in var_name:
                parts = var_name.split('_')
                activity_id = int(parts[1])
                resource_id = int(parts[2])
                time = int(parts[3])
                decoded_solution["resources_usage"].append((activity_id, resource_id, time))

    return decoded_solution

# %%
# Advanced output display
def print_solution(solution):
    print("Thời gian bắt đầu của mỗi hoạt động:")
    for activity, start_time in solution['activities_start_times'].items():
        print(f"  - Hoạt động {activity} bắt đầu tại thời điểm {start_time}")

    print("\nThời gian chạy của mỗi hoạt động:")
    for activity, time in solution['activities_runtime']:
        print(f"  - Hoạt động {activity} đang chạy tại thời điểm {time}")

    print("\nTiêu thụ tài nguyên theo thời gian:")
    resource_usage = {}
    for activity, resource, time in solution['resources_usage']:
        if time not in resource_usage:
            resource_usage[time] = []
        resource_usage[time].append((activity, resource))

    for time, usages in resource_usage.items():
        print(f"  - Tại thời điểm {time}:")
        for activity, resource in usages:
            print(f"    + Hoạt động {activity} tiêu thụ Tài nguyên {resource}")

# %% [markdown]
# Hoạt động (activities):
#
# Mỗi hoạt động có id, duration (thời gian thực hiện), và consumption (tài nguyên tiêu thụ theo dạng {resource_id: quantity}).
# Ví dụ: Hoạt động 3 yêu cầu 3 đơn vị tài nguyên 1 và 1 đơn vị tài nguyên 2.
# Tài nguyên (resources):
#
# Mỗi tài nguyên có id và capacity (khả năng cung cấp tối đa).
# Ví dụ: Tài nguyên 1 có khả năng cung cấp tối đa 5 đơn vị tại mỗi thời điểm.
# Quan hệ phụ thuộc (encode_relation_fs):
#
# (Thêm một vài quan hệ phụ thuộc giữa các hoạt động. Ví dụ, hoạt động 1 phải hoàn thành trước khi hoạt động 2 có thể bắt đầu, và hoạt động 3 phải hoàn thành trước khi hoạt động 4 bắt đầu.)
#
# Giới hạn thời gian (max_time):
# Đặt max_time = 20 để có nhiều thời gian hơn cho các hoạt động, giúp bài toán có thêm không gian để tối ưu.

# %%
# Input
activities = [
    {"id": 0, "duration": 308, "name": "Task 0"},
    {"id": 1, "duration": 10, "name": "Task 1"},
    {"id": 2, "duration": 1, "name": "Task 2"},
    {"id": 3, "duration": 20, "name": "Task 3"},
    {"id": 4, "duration": 2, "name": "Task 4"},
    {"id": 5, "duration": 5, "name": "Task 5"},
    {"id": 6, "duration": 1, "name": "Task 6"}
]

relations = [
    {"task_id_1": 1, "task_id_2": 2, "relation_type": "ea"},
    {"task_id_1": 2, "task_id_2": 3, "relation_type": "ea"},
    {"task_id_1": 3, "task_id_2": 4, "relation_type": "ea"},
    {"task_id_1": 4, "task_id_2": 5, "relation_type": "ea"},
    {"task_id_1": 5, "task_id_2": 6, "relation_type": "ea"}
]

consumptions = [
    {"task_id": 1, "resource_id": 0, "amount": -3},
    {"task_id": 3, "resource_id": 0, "amount": -3},
    {"task_id": 3, "resource_id": 1, "amount": -3},
    {"task_id": 3, "resource_id": 2, "amount": -3},
    {"task_id": 4, "resource_id": 0, "amount": -3},
    {"task_id": 4, "resource_id": 3, "amount": -3},
    {"task_id": 4, "resource_id": 4, "amount": -3},
    {"task_id": 5, "resource_id": 0, "amount": -3},
    {"task_id": 5, "resource_id": 3, "amount": -3},
    {"task_id": 5, "resource_id": 4, "amount": -3}
]

resources = [
    {"id": 0, "capacity": 8, "name": "Resource 0"},
    {"id": 1, "capacity": 8, "name": "Resource 1"},
    {"id": 2, "capacity": 8, "name": "Resource 2"},
    {"id": 3, "capacity": 8, "name": "Resource 3"},
    {"id": 4, "capacity": 8, "name": "Resource 4"},
    {"id": 5, "capacity": 8, "name": "Resource 5"},
    {"id": 6, "capacity": 8, "name": "Resource 6"},
    {"id": 7, "capacity": 8, "name": "Resource 7"},
    {"id": 8, "capacity": 8, "name": "Resource 8"},
    {"id": 9, "capacity": 8, "name": "Resource 9"},
    {"id": 10, "capacity": 8, "name": "Resource 10"}
]

# %%
# Mã hóa các ràng buộc
max_time = 350  # Thiết lập thời gian tối đa cho lịch trình

# Mã hóa các ràng buộc cho mỗi hoạt động
for activity in activities:
    encode_unique_start_instant(solver, vf, max_time, activity["id"])
    encode_start_in_time(solver, vf, max_time, activity["id"], activity["duration"])
    encode_runtime(solver, vf, max_time, activity["id"], activity["duration"])

# Mã hóa các ràng buộc thứ tự giữa các hoạt động theo quan hệ "finish-start"
for relation in relations:
    encode_relation_fs(solver, vf, max_time, relation["task_id_1"], relation["task_id_2"],
                       next(a["duration"] for a in activities if a["id"] == relation["task_id_1"]))

# Thiết lập cấu trúc tiêu thụ tài nguyên cho mỗi hoạt động, đảm bảo mỗi hoạt động có trường 'consumption'
for activity in activities:
    if "consumption" not in activity:
        activity["consumption"] = {}  # Khởi tạo tiêu thụ tài nguyên trống nếu chưa tồn tại

for consumption in consumptions:
    task_id = consumption["task_id"]
    resource_id = consumption["resource_id"]
    amount = -consumption["amount"]

    for activity in activities:
        if activity["id"] == task_id:
            activity["consumption"][resource_id] = amount

# Mã hóa các ràng buộc về tài nguyên
encode_resource_constraint(solver, vf, max_time, activities, resources)

# %%
# Giải bài toán
if solver.solve():
    model = solver.get_model()
    solution = decode_solution(model, vf)
    print("Lời giải:")
    print_solution(solution)
else:
    print("Không có lời giải thỏa mãn.")
# Out:
# Lời giải:
# Thời gian bắt đầu của mỗi hoạt động:
#   - Hoạt động 1 bắt đầu tại thời điểm 3
#   - Hoạt động 2 bắt đầu tại thời điểm 13
#   - Hoạt động 3 bắt đầu tại thời điểm 25
#   - Hoạt động 4 bắt đầu tại thời điểm 99
#   - Hoạt động 5 bắt đầu tại thời điểm 122
#   - Hoạt động 6 bắt đầu tại thời điểm 299
#   - Hoạt động 0 bắt đầu tại thời điểm 4
#
# Thời gian chạy của mỗi hoạt động:
#   - Hoạt động 0 đang chạy tại thời điểm 4
#   - Hoạt động 0 đang chạy tại thời điểm 5
#   - Hoạt động 0 đang chạy tại thời điểm 6
#   - Hoạt động 0 đang chạy tại thời điểm 7
#   - Hoạt động 0 đang chạy tại thời điểm 8
#   - Hoạt động 0 đang chạy tại thời điểm 9
#   - Hoạt động 0 đang chạy tại thời điểm 10
#   - Hoạt động 0 đang chạy tại thời điểm 11
#   - Hoạt động 0 đang chạy tại thời điểm 12
#   - Hoạt động 0 đang chạy tại thời điểm 13
#   - Hoạt động 0 đang chạy tại thời điểm 14
#   - Hoạt động 0 đang chạy tại thời điểm 15
#   - Hoạt động 0 đang chạy tại thời điểm 16
#   - Hoạt động 0 đang chạy tại thời điểm 17
#   - Hoạt động 0 đang chạy tại thời điểm 18
#   - Hoạt động 0 đang chạy tại thời điểm 19
#   - Hoạt động 0 đang chạy tại thời điểm 20
#   - Hoạt động 0 đang chạy tại thời điểm 21
#   - Hoạt động 0 đang chạy tại thời điểm 22
#   - Hoạt động 0 đang chạy tại thời điểm 23
#   - Hoạt động 0 đang chạy tại thời điểm 24
#   - Hoạt động 0 đang chạy tại thời điểm 25
#   - Hoạt động 0 đang chạy tại thời điểm 26
#   - Hoạt động 0 đang chạy tại thời điểm 27
#   - Hoạt động 0 đang chạy tại thời điểm 28
#   - Hoạt động 0 đang chạy tại thời điểm 29
#   - Hoạt động 0 đang chạy tại thời điểm 30
#   - Hoạt động 0 đang chạy tại thời điểm 31
#   - Hoạt động 0 đang chạy tại thời điểm 32
#   - Hoạt động 0 đang chạy tại thời điểm 33
#   - Hoạt động 0 đang chạy tại thời điểm 34
#   - Hoạt động 0 đang chạy tại thời điểm 35
#   - Hoạt động 0 đang chạy tại thời điểm 36
#   - Hoạt động 0 đang chạy tại thời điểm 37
#   - Hoạt động 0 đang chạy tại thời điểm 38
#   - Hoạt động 0 đang chạy tại thời điểm 39
#   - Hoạt động 0 đang chạy tại thời điểm 40
#   - Hoạt động 0 đang chạy tại thời điểm 41
#   - Hoạt động 0 đang chạy tại thời điểm 42
#   - Hoạt động 0 đang chạy tại thời điểm 43
#   - Hoạt động 0 đang chạy tại thời điểm 44
#   - Hoạt động 0 đang chạy tại thời điểm 45
#   - Hoạt động 0 đang chạy tại thời điểm 46
#   - Hoạt động 0 đang chạy tại thời điểm 47
#   - Hoạt động 0 đang chạy tại thời điểm 48
#   - Hoạt động 0 đang chạy tại thời điểm 49
#   - Hoạt động 0 đang chạy tại thời điểm 50
#   - Hoạt động 0 đang chạy tại thời điểm 51
#   - Hoạt động 0 đang chạy tại thời điểm 52
#   - Hoạt động 0 đang chạy tại thời điểm 53
#   - Hoạt động 0 đang chạy tại thời điểm 54
#   - Hoạt động 0 đang chạy tại thời điểm 55
#   - Hoạt động 0 đang chạy tại thời điểm 56
#   - Hoạt động 0 đang chạy tại thời điểm 57
#   - Hoạt động 0 đang chạy tại thời điểm 58
#   - Hoạt động 0 đang chạy tại thời điểm 59
#   - Hoạt động 0 đang chạy tại thời điểm 60
#   - Hoạt động 0 đang chạy tại thời điểm 61
#   - Hoạt động 0 đang chạy tại thời điểm 62
#   - Hoạt động 0 đang chạy tại thời điểm 63
#   - Hoạt động 0 đang chạy tại thời điểm 64
#   - Hoạt động 0 đang chạy tại thời điểm 65
#   - Hoạt động 0 đang chạy tại thời điểm 66
#   - Hoạt động 0 đang chạy tại thời điểm 67
#   - Hoạt động 0 đang chạy tại thời điểm 68
#   - Hoạt động 0 đang chạy tại thời điểm 69
#   - Hoạt động 0 đang chạy tại thời điểm 70
#   - Hoạt động 0 đang chạy tại thời điểm 71
#   - Hoạt động 0 đang chạy tại thời điểm 72
#   - Hoạt động 0 đang chạy tại thời điểm 73
#   - Hoạt động 0 đang chạy tại thời điểm 74
#   - Hoạt động 0 đang chạy tại thời điểm 75
#   - Hoạt động 0 đang chạy tại thời điểm 76
#   - Hoạt động 0 đang chạy tại thời điểm 77
#   - Hoạt động 0 đang chạy tại thời điểm 78
#   - Hoạt động 0 đang chạy tại thời điểm 79
#   - Hoạt động 0 đang chạy tại thời điểm 80
#   - Hoạt động 0 đang chạy tại thời điểm 81
#   - Hoạt động 0 đang chạy tại thời điểm 82
#   - Hoạt động 0 đang chạy tại thời điểm 83
#   - Hoạt động 0 đang chạy tại thời điểm 84
#   - Hoạt động 0 đang chạy tại thời điểm 85
#   - Hoạt động 0 đang chạy tại thời điểm 86
#   - Hoạt động 0 đang chạy tại thời điểm 87
#   - Hoạt động 0 đang chạy tại thời điểm 88
#   - Hoạt động 0 đang chạy tại thời điểm 89
#   - Hoạt động 0 đang chạy tại thời điểm 90
#   - Hoạt động 0 đang chạy tại thời điểm 91
#   - Hoạt động 0 đang chạy tại thời điểm 92
#   - Hoạt động 0 đang chạy tại thời điểm 93
#   - Hoạt động 0 đang chạy tại thời điểm 94
#   - Hoạt động 0 đang chạy tại thời điểm 95
#   - Hoạt động 0 đang chạy tại thời điểm 96
#   - Hoạt động 0 đang chạy tại thời điểm 97
#   - Hoạt động 0 đang chạy tại thời điểm 98
#   - Hoạt động 0 đang chạy tại thời điểm 99
#   - Hoạt động 0 đang chạy tại thời điểm 100
#   - Hoạt động 0 đang chạy tại thời điểm 101
#   - Hoạt động 0 đang chạy tại thời điểm 102
#   - Hoạt động 0 đang chạy tại thời điểm 103
#   - Hoạt động 0 đang chạy tại thời điểm 104
#   - Hoạt động 0 đang chạy tại thời điểm 105
#   - Hoạt động 0 đang chạy tại thời điểm 106
#   - Hoạt động 0 đang chạy tại thời điểm 107
#   - Hoạt động 0 đang chạy tại thời điểm 108
#   - Hoạt động 0 đang chạy tại thời điểm 109
#   - Hoạt động 0 đang chạy tại thời điểm 110
#   - Hoạt động 0 đang chạy tại thời điểm 111
#   - Hoạt động 0 đang chạy tại thời điểm 112
#   - Hoạt động 0 đang chạy tại thời điểm 113
#   - Hoạt động 0 đang chạy tại thời điểm 114
#   - Hoạt động 0 đang chạy tại thời điểm 115
#   - Hoạt động 0 đang chạy tại thời điểm 116
#   - Hoạt động 0 đang chạy tại thời điểm 117
#   - Hoạt động 0 đang chạy tại thời điểm 118
#   - Hoạt động 0 đang chạy tại thời điểm 119
#   - Hoạt động 0 đang chạy tại thời điểm 120
#   - Hoạt động 0 đang chạy tại thời điểm 121
#   - Hoạt động 0 đang chạy tại thời điểm 122
#   - Hoạt động 0 đang chạy tại thời điểm 123
#   - Hoạt động 0 đang chạy tại thời điểm 124
#   - Hoạt động 0 đang chạy tại thời điểm 125
#   - Hoạt động 0 đang chạy tại thời điểm 126
#   - Hoạt động 0 đang chạy tại thời điểm 127
#   - Hoạt động 0 đang chạy tại thời điểm 128
#   - Hoạt động 0 đang chạy tại thời điểm 129
#   - Hoạt động 0 đang chạy tại thời điểm 130
#   - Hoạt động 0 đang chạy tại thời điểm 131
#   - Hoạt động 0 đang chạy tại thời điểm 132
#   - Hoạt động 0 đang chạy tại thời điểm 133
#   - Hoạt động 0 đang chạy tại thời điểm 134
#   - Hoạt động 0 đang chạy tại thời điểm 135
#   - Hoạt động 0 đang chạy tại thời điểm 136
#   - Hoạt động 0 đang chạy tại thời điểm 137
#   - Hoạt động 0 đang chạy tại thời điểm 138
#   - Hoạt động 0 đang chạy tại thời điểm 139
#   - Hoạt động 0 đang chạy tại thời điểm 140
#   - Hoạt động 0 đang chạy tại thời điểm 141
#   - Hoạt động 0 đang chạy tại thời điểm 142
#   - Hoạt động 0 đang chạy tại thời điểm 143
#   - Hoạt động 0 đang chạy tại thời điểm 144
#   - Hoạt động 0 đang chạy tại thời điểm 145
#   - Hoạt động 0 đang chạy tại thời điểm 146
#   - Hoạt động 0 đang chạy tại thời điểm 147
#   - Hoạt động 0 đang chạy tại thời điểm 148
#   - Hoạt động 0 đang chạy tại thời điểm 149
#   - Hoạt động 0 đang chạy tại thời điểm 150
#   - Hoạt động 0 đang chạy tại thời điểm 151
#   - Hoạt động 0 đang chạy tại thời điểm 152
#   - Hoạt động 0 đang chạy tại thời điểm 153
#   - Hoạt động 0 đang chạy tại thời điểm 154
#   - Hoạt động 0 đang chạy tại thời điểm 155
#   - Hoạt động 0 đang chạy tại thời điểm 156
#   - Hoạt động 0 đang chạy tại thời điểm 157
#   - Hoạt động 0 đang chạy tại thời điểm 158
#   - Hoạt động 0 đang chạy tại thời điểm 159
#   - Hoạt động 0 đang chạy tại thời điểm 160
#   - Hoạt động 0 đang chạy tại thời điểm 161
#   - Hoạt động 0 đang chạy tại thời điểm 162
#   - Hoạt động 0 đang chạy tại thời điểm 163
#   - Hoạt động 0 đang chạy tại thời điểm 164
#   - Hoạt động 0 đang chạy tại thời điểm 165
#   - Hoạt động 0 đang chạy tại thời điểm 166
#   - Hoạt động 0 đang chạy tại thời điểm 167
#   - Hoạt động 0 đang chạy tại thời điểm 168
#   - Hoạt động 0 đang chạy tại thời điểm 169
#   - Hoạt động 0 đang chạy tại thời điểm 170
#   - Hoạt động 0 đang chạy tại thời điểm 171
#   - Hoạt động 0 đang chạy tại thời điểm 172
#   - Hoạt động 0 đang chạy tại thời điểm 173
#   - Hoạt động 0 đang chạy tại thời điểm 174
#   - Hoạt động 0 đang chạy tại thời điểm 175
#   - Hoạt động 0 đang chạy tại thời điểm 176
#   - Hoạt động 0 đang chạy tại thời điểm 177
#   - Hoạt động 0 đang chạy tại thời điểm 178
#   - Hoạt động 0 đang chạy tại thời điểm 179
#   - Hoạt động 0 đang chạy tại thời điểm 180
#   - Hoạt động 0 đang chạy tại thời điểm 181
#   - Hoạt động 0 đang chạy tại thời điểm 182
#   - Hoạt động 0 đang chạy tại thời điểm 183
#   - Hoạt động 0 đang chạy tại thời điểm 184
#   - Hoạt động 0 đang chạy tại thời điểm 185
#   - Hoạt động 0 đang chạy tại thời điểm 186
#   - Hoạt động 0 đang chạy tại thời điểm 187
#   - Hoạt động 0 đang chạy tại thời điểm 188
#   - Hoạt động 0 đang chạy tại thời điểm 189
#   - Hoạt động 0 đang chạy tại thời điểm 190
#   - Hoạt động 0 đang chạy tại thời điểm 191
#   - Hoạt động 0 đang chạy tại thời điểm 192
#   - Hoạt động 0 đang chạy tại thời điểm 193
#   - Hoạt động 0 đang chạy tại thời điểm 194
#   - Hoạt động 0 đang chạy tại thời điểm 195
#   - Hoạt động 0 đang chạy tại thời điểm 196
#   - Hoạt động 0 đang chạy tại thời điểm 197
#   - Hoạt động 0 đang chạy tại thời điểm 198
#   - Hoạt động 0 đang chạy tại thời điểm 199
#   - Hoạt động 0 đang chạy tại thời điểm 200
#   - Hoạt động 0 đang chạy tại thời điểm 201
#   - Hoạt động 0 đang chạy tại thời điểm 202
#   - Hoạt động 0 đang chạy tại thời điểm 203
#   - Hoạt động 0 đang chạy tại thời điểm 204
#   - Hoạt động 0 đang chạy tại thời điểm 205
#   - Hoạt động 0 đang chạy tại thời điểm 206
#   - Hoạt động 0 đang chạy tại thời điểm 207
#   - Hoạt động 0 đang chạy tại thời điểm 208
#   - Hoạt động 0 đang chạy tại thời điểm 209
#   - Hoạt động 0 đang chạy tại thời điểm 210
#   - Hoạt động 0 đang chạy tại thời điểm 211
#   - Hoạt động 0 đang chạy tại thời điểm 212
#   - Hoạt động 0 đang chạy tại thời điểm 213
#   - Hoạt động 0 đang chạy tại thời điểm 214
#   - Hoạt động 0 đang chạy tại thời điểm 215
#   - Hoạt động 0 đang chạy tại thời điểm 216
#   - Hoạt động 0 đang chạy tại thời điểm 217
#   - Hoạt động 0 đang chạy tại thời điểm 218
#   - Hoạt động 0 đang chạy tại thời điểm 219
#   - Hoạt động 0 đang chạy tại thời điểm 220
#   - Hoạt động 0 đang chạy tại thời điểm 221
#   - Hoạt động 0 đang chạy tại thời điểm 222
#   - Hoạt động 0 đang chạy tại thời điểm 223
#   - Hoạt động 0 đang chạy tại thời điểm 224
#   - Hoạt động 0 đang chạy tại thời điểm 225
#   - Hoạt động 0 đang chạy tại thời điểm 226
#   - Hoạt động 0 đang chạy tại thời điểm 227
#   - Hoạt động 0 đang chạy tại thời điểm 228
#   - Hoạt động 0 đang chạy tại thời điểm 229
#   - Hoạt động 0 đang chạy tại thời điểm 230
#   - Hoạt động 0 đang chạy tại thời điểm 231
#   - Hoạt động 0 đang chạy tại thời điểm 232
#   - Hoạt động 0 đang chạy tại thời điểm 233
#   - Hoạt động 0 đang chạy tại thời điểm 234
#   - Hoạt động 0 đang chạy tại thời điểm 235
#   - Hoạt động 0 đang chạy tại thời điểm 236
#   - Hoạt động 0 đang chạy tại thời điểm 237
#   - Hoạt động 0 đang chạy tại thời điểm 238
#   - Hoạt động 0 đang chạy tại thời điểm 239
#   - Hoạt động 0 đang chạy tại thời điểm 240
#   - Hoạt động 0 đang chạy tại thời điểm 241
#   - Hoạt động 0 đang chạy tại thời điểm 242
#   - Hoạt động 0 đang chạy tại thời điểm 243
#   - Hoạt động 0 đang chạy tại thời điểm 244
#   - Hoạt động 0 đang chạy tại thời điểm 245
#   - Hoạt động 0 đang chạy tại thời điểm 246
#   - Hoạt động 0 đang chạy tại thời điểm 247
#   - Hoạt động 0 đang chạy tại thời điểm 248
#   - Hoạt động 0 đang chạy tại thời điểm 249
#   - Hoạt động 0 đang chạy tại thời điểm 250
#   - Hoạt động 0 đang chạy tại thời điểm 251
#   - Hoạt động 0 đang chạy tại thời điểm 252
#   - Hoạt động 0 đang chạy tại thời điểm 253
#   - Hoạt động 0 đang chạy tại thời điểm 254
#   - Hoạt động 0 đang chạy tại thời điểm 255
#   - Hoạt động 0 đang chạy tại thời điểm 256
#   - Hoạt động 0 đang chạy tại thời điểm 257
#   - Hoạt động 0 đang chạy tại thời điểm 258
#   - Hoạt động 0 đang chạy tại thời điểm 259
#   - Hoạt động 0 đang chạy tại thời điểm 260
#   - Hoạt động 0 đang chạy tại thời điểm 261
#   - Hoạt động 0 đang chạy tại thời điểm 262
#   - Hoạt động 0 đang chạy tại thời điểm 263
#   - Hoạt động 0 đang chạy tại thời điểm 264
#   - Hoạt động 0 đang chạy tại thời điểm 265
#   - Hoạt động 0 đang chạy tại thời điểm 266
#   - Hoạt động 0 đang chạy tại thời điểm 267
#   - Hoạt động 0 đang chạy tại thời điểm 268
#   - Hoạt động 0 đang chạy tại thời điểm 269
#   - Hoạt động 0 đang chạy tại thời điểm 270
#   - Hoạt động 0 đang chạy tại thời điểm 271
#   - Hoạt động 0 đang chạy tại thời điểm 272
#   - Hoạt động 0 đang chạy tại thời điểm 273
#   - Hoạt động 0 đang chạy tại thời điểm 274
#   - Hoạt động 0 đang chạy tại thời điểm 275
#   - Hoạt động 0 đang chạy tại thời điểm 276
#   - Hoạt động 0 đang chạy tại thời điểm 277
#   - Hoạt động 0 đang chạy tại thời điểm 278
#   - Hoạt động 0 đang chạy tại thời điểm 279
#   - Hoạt động 0 đang chạy tại thời điểm 280
#   - Hoạt động 0 đang chạy tại thời điểm 281
#   - Hoạt động 0 đang chạy tại thời điểm 282
#   - Hoạt động 0 đang chạy tại thời điểm 283
#   - Hoạt động 0 đang chạy tại thời điểm 284
#   - Hoạt động 0 đang chạy tại thời điểm 285
#   - Hoạt động 0 đang chạy tại thời điểm 286
#   - Hoạt động 0 đang chạy tại thời điểm 287
#   - Hoạt động 0 đang chạy tại thời điểm 288
#   - Hoạt động 0 đang chạy tại thời điểm 289
#   - Hoạt động 0 đang chạy tại thời điểm 290
#   - Hoạt động 0 đang chạy tại thời điểm 291
#   - Hoạt động 0 đang chạy tại thời điểm 292
#   - Hoạt động 0 đang chạy tại thời điểm 293
#   - Hoạt động 0 đang chạy tại thời điểm 294
#   - Hoạt động 0 đang chạy tại thời điểm 295
#   - Hoạt động 0 đang chạy tại thời điểm 296
#   - Hoạt động 0 đang chạy tại thời điểm 297
#   - Hoạt động 0 đang chạy tại thời điểm 298
#   - Hoạt động 0 đang chạy tại thời điểm 299
#   - Hoạt động 0 đang chạy tại thời điểm 300
#   - Hoạt động 0 đang chạy tại thời điểm 301
#   - Hoạt động 0 đang chạy tại thời điểm 302
#   - Hoạt động 0 đang chạy tại thời điểm 303
#   - Hoạt động 0 đang chạy tại thời điểm 304
#   - Hoạt động 0 đang chạy tại thời điểm 305
#   - Hoạt động 0 đang chạy tại thời điểm 306
#   - Hoạt động 0 đang chạy tại thời điểm 307
#   - Hoạt động 0 đang chạy tại thời điểm 308
#   - Hoạt động 0 đang chạy tại thời điểm 309
#   - Hoạt động 0 đang chạy tại thời điểm 310
#   - Hoạt động 0 đang chạy tại thời điểm 311
#   - Hoạt động 1 đang chạy tại thời điểm 3
#   - Hoạt động 1 đang chạy tại thời điểm 4
#   - Hoạt động 1 đang chạy tại thời điểm 5
#   - Hoạt động 1 đang chạy tại thời điểm 6
#   - Hoạt động 1 đang chạy tại thời điểm 7
#   - Hoạt động 1 đang chạy tại thời điểm 8
#   - Hoạt động 1 đang chạy tại thời điểm 9
#   - Hoạt động 1 đang chạy tại thời điểm 10
#   - Hoạt động 1 đang chạy tại thời điểm 11
#   - Hoạt động 1 đang chạy tại thời điểm 12
#   - Hoạt động 2 đang chạy tại thời điểm 13
#   - Hoạt động 3 đang chạy tại thời điểm 25
#   - Hoạt động 3 đang chạy tại thời điểm 26
#   - Hoạt động 3 đang chạy tại thời điểm 27
#   - Hoạt động 3 đang chạy tại thời điểm 28
#   - Hoạt động 3 đang chạy tại thời điểm 29
#   - Hoạt động 3 đang chạy tại thời điểm 30
#   - Hoạt động 3 đang chạy tại thời điểm 31
#   - Hoạt động 3 đang chạy tại thời điểm 32
#   - Hoạt động 3 đang chạy tại thời điểm 33
#   - Hoạt động 3 đang chạy tại thời điểm 34
#   - Hoạt động 3 đang chạy tại thời điểm 35
#   - Hoạt động 3 đang chạy tại thời điểm 36
#   - Hoạt động 3 đang chạy tại thời điểm 37
#   - Hoạt động 3 đang chạy tại thời điểm 38
#   - Hoạt động 3 đang chạy tại thời điểm 39
#   - Hoạt động 3 đang chạy tại thời điểm 40
#   - Hoạt động 3 đang chạy tại thời điểm 41
#   - Hoạt động 3 đang chạy tại thời điểm 42
#   - Hoạt động 3 đang chạy tại thời điểm 43
#   - Hoạt động 3 đang chạy tại thời điểm 44
#   - Hoạt động 4 đang chạy tại thời điểm 99
#   - Hoạt động 4 đang chạy tại thời điểm 100
#   - Hoạt động 5 đang chạy tại thời điểm 122
#   - Hoạt động 5 đang chạy tại thời điểm 123
#   - Hoạt động 5 đang chạy tại thời điểm 124
#   - Hoạt động 5 đang chạy tại thời điểm 125
#   - Hoạt động 5 đang chạy tại thời điểm 126
#   - Hoạt động 6 đang chạy tại thời điểm 299
#
# Tiêu thụ tài nguyên theo thời gian:
#   - Tại thời điểm 0:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#   - Tại thời điểm 1:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 2:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 3:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 4:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 5:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 6:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 7:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 8:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 9:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 10:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 11:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 12:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 13:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 14:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 15:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 16:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 17:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 18:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 19:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 20:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 21:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 22:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 23:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 24:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 25:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 26:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 27:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 28:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 29:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 30:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 31:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 32:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 33:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 34:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 35:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 36:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 37:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 38:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 39:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 40:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 41:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 42:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 43:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 44:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 99:
#     + Hoạt động 4 tiêu thụ Tài nguyên 0
#     + Hoạt động 4 tiêu thụ Tài nguyên 0
#     + Hoạt động 4 tiêu thụ Tài nguyên 0
#     + Hoạt động 4 tiêu thụ Tài nguyên 3
#     + Hoạt động 4 tiêu thụ Tài nguyên 3
#     + Hoạt động 4 tiêu thụ Tài nguyên 3
#     + Hoạt động 4 tiêu thụ Tài nguyên 4
#     + Hoạt động 4 tiêu thụ Tài nguyên 4
#     + Hoạt động 4 tiêu thụ Tài nguyên 4
#   - Tại thời điểm 100:
#     + Hoạt động 4 tiêu thụ Tài nguyên 0
#     + Hoạt động 4 tiêu thụ Tài nguyên 0
#     + Hoạt động 4 tiêu thụ Tài nguyên 0
#     + Hoạt động 4 tiêu thụ Tài nguyên 3
#     + Hoạt động 4 tiêu thụ Tài nguyên 3
#     + Hoạt động 4 tiêu thụ Tài nguyên 3
#     + Hoạt động 4 tiêu thụ Tài nguyên 4
#     + Hoạt động 4 tiêu thụ Tài nguyên 4
#     + Hoạt động 4 tiêu thụ Tài nguyên 4
#   - Tại thời điểm 103:
#     + Hoạt động 4 tiêu thụ Tài nguyên 0
#     + Hoạt động 4 tiêu thụ Tài nguyên 0
#     + Hoạt động 4 tiêu thụ Tài nguyên 0
#     + Hoạt động 4 tiêu thụ Tài nguyên 3
#     + Hoạt động 4 tiêu thụ Tài nguyên 3
#     + Hoạt động 4 tiêu thụ Tài nguyên 3
#     + Hoạt động 4 tiêu thụ Tài nguyên 4
#     + Hoạt động 4 tiêu thụ Tài nguyên 4
#     + Hoạt động 4 tiêu thụ Tài nguyên 4
#   - Tại thời điểm 122:
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#   - Tại thời điểm 123:
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#   - Tại thời điểm 124:
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#   - Tại thời điểm 125:
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#   - Tại thời điểm 126:
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 0
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 3
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#     + Hoạt động 5 tiêu thụ Tài nguyên 4
#   - Tại thời điểm 250:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#   - Tại thời điểm 251:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#   - Tại thời điểm 252:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#   - Tại thời điểm 253:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#   - Tại thời điểm 254:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#   - Tại thời điểm 255:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#   - Tại thời điểm 256:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#   - Tại thời điểm 257:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#   - Tại thời điểm 258:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#   - Tại thời điểm 259:
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 1 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 260:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 261:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 262:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 263:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 264:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 265:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 266:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 267:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 268:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 269:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 270:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 271:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 272:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 273:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 274:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 275:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 276:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 277:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#   - Tại thời điểm 278:
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 0
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 1
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2
#     + Hoạt động 3 tiêu thụ Tài nguyên 2

# %%
import tracemalloc
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from pysat.solvers import Glucose3
from concurrent.futures import ThreadPoolExecutor

# Function to evaluate memory usage and solve time for a given encoding type
def evaluate_single_run(vf, max_time, activities, relations, resources, consumptions, encoding_type):
    solver = Glucose3()  # Create a new solver instance for each run

    # Start tracking memory before encoding
    tracemalloc.start()

    # Encode activities, relations, and resources
    for activity in activities:
        encode_unique_start_instant(solver, vf, max_time, activity["id"])
        encode_start_in_time(solver, vf, max_time, activity["id"], activity["duration"])
        encode_runtime(solver, vf, max_time, activity["id"], activity["duration"])

    for relation in relations:
        encode_relation_fs(solver, vf, max_time, relation["task_id_1"], relation["task_id_2"],
                           next(a["duration"] for a in activities if a["id"] == relation["task_id_1"]))

    for activity in activities:
        if "consumption" not in activity:
            activity["consumption"] = {}
    for consumption in consumptions:
        task_id = consumption["task_id"]
        resource_id = consumption["resource_id"]
        amount = -consumption["amount"]
        for activity in activities:
            if activity["id"] == task_id:
                activity["consumption"][resource_id] = amount

    # Choose encoding method
    if encoding_type == "Potenzmeng":
        encode_resource_constraint_powerset(solver, vf, max_time, activities, resources)
    elif encoding_type == "BCC":
        encode_resource_constraint_cardinality(solver, vf, max_time, activities, resources)

    # Get peak memory usage and stop memory tracking
    _, peak_memory = tracemalloc.get_traced_memory()
    tracemalloc.stop()

    # Measure solve time
    start_time = time.time()
    solver.solve()
    end_time = time.time()
    solve_time = (end_time - start_time) * 1000  # Convert to milliseconds

    solver.delete()  # Clean up solver instance

    return peak_memory / (1024 * 1024), solve_time  # Return in MB and ms

# Initialize lists to store results
memory_usage_potenzmeng = []
solve_time_potenzmeng = []
memory_usage_bcc = []
solve_time_bcc = []

# Initialize variable factory once
vf = VariableFactory()
max_time = 350  # Max scheduling time based on the problem description

# Run evaluations in parallel
with ThreadPoolExecutor() as executor:
    # Create tasks for each method, repeated 100 times
    potenzmeng_tasks = [
        executor.submit(
            evaluate_single_run, vf, max_time, activities, relations, resources, consumptions, "Potenzmeng"
        ) for _ in range(100)
    ]
    bcc_tasks = [
        executor.submit(
            evaluate_single_run, vf, max_time, activities, relations, resources, consumptions, "BCC"
        ) for _ in range(100)
    ]

    # Gather results for Potenzmeng
    for task in potenzmeng_tasks:
        memory, time_taken = task.result()
        memory_usage_potenzmeng.append(memory)
        solve_time_potenzmeng.append(time_taken)

    # Gather results for BCC
    for task in bcc_tasks:
        memory, time_taken = task.result()
        memory_usage_bcc.append(memory)
        solve_time_bcc.append(time_taken)

# Plotting results with trendlines
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot Memory Usage
ax[0].scatter(memory_usage_potenzmeng, memory_usage_bcc, color='teal', s=10, label="Data Points")
ax[0].set_xlabel("Speicherverbrauch beim Codieren mit Potenzmeng (MB)", fontsize=12)
ax[0].set_ylabel("Speicherverbrauch beim Codieren mit BCC (MB)", fontsize=12)
ax[0].set_title("Đồ thị tiêu thụ bộ nhớ khi mã hóa RCPSP", fontsize=14)

# Tính và vẽ đường trendline cho bộ nhớ tiêu thụ
slope, intercept, _, _, _ = linregress(memory_usage_potenzmeng, memory_usage_bcc)
trendline_y = np.array(memory_usage_potenzmeng) * slope + intercept
ax[0].plot(memory_usage_potenzmeng, trendline_y, color='red', linestyle="--", label="Trendline")
ax[0].legend()

# Đồ thị 2: Thời gian giải SAT
ax[1].scatter(solve_time_potenzmeng, solve_time_bcc, color='coral', s=10, label="Data Points")
ax[1].set_xlabel("Thời gian giải SAT trung bình với Potenzmeng (ms)", fontsize=12)
ax[1].set_ylabel("Thời gian giải SAT trung bình với BCC (ms)", fontsize=12)
ax[1].set_title("Đồ thị thời gian giải SAT của RCPSP", fontsize=14)

# Tính và vẽ đường trendline cho thời gian giải SAT
slope, intercept, _, _, _ = linregress(solve_time_potenzmeng, solve_time_bcc)
trendline_y = np.array(solve_time_potenzmeng) * slope + intercept
ax[1].plot(solve_time_potenzmeng, trendline_y, color='blue', linestyle="--", label="Trendline")
ax[1].legend()

plt.tight_layout()
plt.show()

# In kết quả trung bình
print("Kết quả trung bình:")
print(f"Bộ nhớ tiêu thụ trung bình với Potenzmeng: {np.mean(memory_usage_potenzmeng):.2f} MB")
print(f"Bộ nhớ tiêu thụ trung bình với BCC: {np.mean(memory_usage_bcc):.2f} MB")
print(f"Thời gian giải SAT trung bình với Potenzmeng: {np.mean(solve_time_potenzmeng):.2f} ms")
print(f"Thời gian giải SAT trung bình với BCC: {np.mean(solve_time_bcc):.2f} ms")
# Out:
# Kết quả trung bình của 100 lần chạy:
# Tiêu thụ bộ nhớ trung bình với Potenzmeng: 0.03 MB
# Tiêu thụ bộ nhớ trung bình với BCC: 0.22 MB
# Thời gian giải SAT trung bình với Potenzmeng: 31.19 ms
# Thời gian giải SAT trung bình với BCC: 17.69 ms
